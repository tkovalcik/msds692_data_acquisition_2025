# %% [markdown]
# Using the DATA_GOV_API_KEY, retrieve data from `https://data.sfgov.org/resource/wg3w-h783`, SF Police Department Report Data.
#
# complete store_to_gcs() to store retrieved data to GCS, and retrieve_data_from_gcs() to retrieve data from GCS.
# - store_to_gcs(service_account_key, project_id, bucket_name, file_name, data) : upload data as file_name on the given gcs.
# - retrieve_data_from_gcs(service_account_key, project_id, bucket_name, file_name, key_list) : return a list of list which includes values corresponding to keys in key_list.
# If
# ```
# key_list = ['incident_datetime', 'report_datetime', 'incident_code',
#             'incident_category', 'incident_description', 'latitude',
#             'longitude', 'police_district']
# ```
# This should return
# ```
# [['2025-08-26T23:17:00.000',
#   '2025-08-26T23:17:00.000',
#   '07041',
#   'Recovered Vehicle',
#   'Vehicle, Recovered, Auto',
#   None,
#   None,
#   'Out of SF'],
#  ['2025-08-27T00:37:00.000',
#   '2025-08-27T00:37:00.000',
#   '04134',
#   'Assault',
#   'Battery',
#   '37.78041458129883',
#   '-122.44901275634766',
#   'Park'],....]
# ```
# If a key doesn't exist, its value should be `None`

# %%
import datetime
import json
import os 

from dotenv import load_dotenv
from google.oauth2 import service_account
from google.cloud import storage
import requests

# %%
path = '../.env'

load_dotenv(path)

api_key = os.getenv("DATA_GOV_API_KEY")

# %%
print(api_key)
# This is ok behavior to print out the api_key on my local machine since it's reading the .env file from my local machine
# since my .env file is included as part of .gitignore, it will not be uploaded and others will not have access to it
# Out:
# ggSUAz1KnUlytqpybgk5bLxfwKlRwgPKn89xKsOc

# %% [markdown]
# - Typically authorization in a header uses the format of..
# ```
# headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}
# ```
# However, based on the [documentaiton](https://api.data.gov/docs/developer-manual/), I followed the following format.
#
# Also, the data specific meta data and details can be searchable. (Ex.[link](https://data.sfgov.org/Public-Safety/Police-Department-Incident-Reports-2018-to-Present/wg3w-h783/about_data))

# %%
url = 'https://data.sfgov.org/resource/wg3w-h783'
header = {'X-Api-Key':api_key}

response = requests.get(url, headers=header)

# %%
data = response.json()
print(data)
# Out:
# [{'row_id': '150750507041', 'incident_datetime': '2025-08-26T23:17:00.000', 'incident_date': '2025-08-26T00:00:00.000', 'incident_time': '23:17', 'incident_year': '2025', 'incident_day_of_week': 'Tuesday', 'report_datetime': '2025-08-26T23:17:00.000', 'incident_id': '1507505', 'incident_number': '250333102', 'report_type_code': 'VS', 'report_type_description': 'Vehicle Supplement', 'incident_code': '07041', 'incident_category': 'Recovered Vehicle', 'incident_subcategory': 'Recovered Vehicle', 'incident_description': 'Vehicle, Recovered, Auto', 'resolution': 'Open or Active', 'police_district': 'Out of SF', 'data_as_of': '2025-08-28T09:38:07.000', 'data_loaded_at': '2025-08-29T09:53:03.000'}, {'row_id': '150752104134', 'incident_datetime': '2025-08-27T00:37:00.000', 'incident_date': '2025-08-27T00:00:00.000', 'incident_time': '00:37', 'incident_year': '2025', 'incident_day_of_week': 'Wednesday', 'report_datetime': '2025-08-27T00:37:00.000', 'incident_id': '1507521', 'incident_number': '250479881', 'cad_number': '252390049', 'report_type_code': 'II', 'report_type_description': 'Initial', 'incident_code': '04134', 'incident_category': 'Assault', 'incident_subcategory': 'Simple Assault', 'incident_description': 'Battery', 'resolution': 'Open or Active', 'intersection': 'EWING TER \\ JEAN WAY', 'cnn': '33557000', 'police_district': 'Park', 'analysis_neighborhood': 'Lone Mountain/USF', 'supervisor_district': '1', 'supervisor_district_2012': '1', 'latitude': '37.78041458129883', 'longitude': '-122.44901275634766', 'point': {'type': 'Point', 'coordinates': [-122.449012756, 37.780414581]}, 'data_as_of': '2025-08-28T09:38:07.000', 'data_loaded_at': '2025-08-29T09:53:03.000', ':@computed_region_jwn9_ihcz': '12', ':@computed_region_26cr_cadq': '4', ':@computed_region_qgnn_b9vv': '7'}, {'row_id': '150762309027', 'incident_datetime': '2025-07-17T15:00:00.000', 'incident_date': '2025-07-17T00:00:00.000', 'incident_time': '15:00', 'incident_year': '2025', 'incident_day_of_week': 'Thursday', 'report_datetime': '2025-08-27T11:55:00.000', 'incident_id': '1507623', 'incident_number': '250480775', 'cad_number': '252391585', 'report_type_code': 'II', 'report_type_description': 'Initial', 'incident_code': '09027', 'incident_category': 'Fraud', 'incident_subcategory': 'Fraud', 'incident_description': 'False Personation', 'resolution': 'Open or Active', 'intersection': 'COLE ST \\ FULTON ST', 'cnn': '26469000', 'police_district': 'Park', 'analysis_neighborhood': 'Lone Mountain/USF', 'supervisor_district': '1', 'supervisor_district_2012': '1', 'latitude': '37.775177001953125', 'longitude': '-122.45135498046875', 'point': {'type': 'Point', 'coordinates': [-122.45135498, 37.775177002]}, 'data_as_of': '2025-08-28T09:38:07.000', 'data_loaded_at': '2025-08-29T09:53:03.000', ':@computed_region_jwn9_ihcz': '12', ':@computed_region_26cr_cadq': '4', ':@computed_region_qgnn_b9vv': '7'}, {'row_id': '150740506244', 'incident_datetime': '2025-08-23T21:30:00.000', 'incident_date': '2025-08-23T00:00:00.000', 'incident_time': '21:30', 'incident_year': '2025', 'incident_day_of_week': 'Saturday', 'report_datetime': '2025-08-24T14:53:00.000', 'incident_id': '1507405', 'incident_number': '256091227', 'report_type_code': 'II', 'report_type_description': 'Coplogic Initial', 'filed_online': True, 'incident_code': '06244', 'incident_category': 'Larceny Theft', 'incident_subcategory': 'Larceny - From Vehicle', 'incident_description': 'Theft, From Locked Vehicle, >$950', 'resolution': 'Open or Active', 'intersection': 'GOUGH ST \\ LILY ST', 'cnn': '25905000', 'police_district': 'Northern', 'analysis_neighborhood': 'Hayes Valley', 'supervisor_district': '6', 'supervisor_district_2012': '5', 'latitude': '37.77455139160156', 'longitude': '-122.42250061035156', 'point': {'type': 'Point', 'coordinates': [-122.42250061, 37.774551392]}, 'data_as_of': '2025-08-27T09:38:07.000', 'data_loaded_at': '2025-08-28T09:53:00.000', ':@computed_region_jwn9_ihcz': '21', ':@computed_region_n4xg_c4p ...

# %% [markdown]
# Create store_to_gcs(service_account_key, project_id, bucket_name, file_name, data) which upload data as file_name on the given gcs.

# %%
def store_to_gcs(service_account_key: str,
                 project_id: str,
                 bucket_name: str,
                 file_name: str,
                 data: str) -> None:    
    credentials = service_account.Credentials.from_service_account_file(service_account_key)
    # Create a client  to bundle configuration needed for API requests.
    client = storage.Client(project=project_id,
                            credentials=credentials)
    # Access a bucket 
    bucket = client.bucket(bucket_name)
    # Access an object (blob) in a bucket
    file = bucket.blob(file_name)
    file.upload_from_string(data)
    
    # content = json.loads(file.download_as_string())

    # output = []

    # for data in content:
    #     row = []
        
    #     for key in key_list:
    #         row.append(data.get(key, None))
    #     output.append(row)
    # return output

# %%
service_account_key = os.getenv("GCP_SERVICE_ACCOUNT_KEY")
project_id = os.getenv("GCP_PROJECT_ID")
bucket_name = os.getenv("GCP_BUCKET_NAME")
file_name = f"sf_police_report/{datetime.date.today()}.json"
store_to_gcs(service_account_key,
            project_id,
            bucket_name,
            file_name,
            json.dumps(data, indent=4))

# %% [markdown]
# Complete retrieve_data_from_gcs() to return a list of list which includes values corresponding to keys in key_list.
# If
# ```
# key_list = ['incident_datetime', 'report_datetime', 'incident_code',
#             'incident_category', 'incident_description', 'latitude',
#             'longitude', 'police_district']
# ```
# This should return
# ```
# [['2025-08-26T23:17:00.000',
#   '2025-08-26T23:17:00.000',
#   '07041',
#   'Recovered Vehicle',
#   'Vehicle, Recovered, Auto',
#   None,
#   None,
#   'Out of SF'],
#  ['2025-08-27T00:37:00.000',
#   '2025-08-27T00:37:00.000',
#   '04134',
#   'Assault',
#   'Battery',
#   '37.78041458129883',
#   '-122.44901275634766',
#   'Park'],....]
# ```
# If a key doesn't exist, its value should be `None`

# %%
def retrieve_data_from_gcs(service_account_key: str,
                           project_id: str,
                           bucket_name: str,
                           file_name: str,
                           key_list: list
                           ) -> list:
    credentials = service_account.Credentials.from_service_account_file(service_account_key)
    # Create a client  to bundle configuration needed for API requests.
    client = storage.Client(project=project_id,
                            credentials=credentials)
    # Access a bucket 
    bucket = client.bucket(bucket_name)
    # Access an object (blob) in a bucket
    file = bucket.blob(file_name)
    content = json.loads(file.download_as_string())

    output = []
    for data in content:
        row = []
        
        for key in key_list:
            row.append(data.get(key, None))
        output.append(row)
    return output

# %%
key_list = ['incident_datetime', 'report_datetime', 'incident_code',
            'incident_category', 'incident_description', 'latitude',
            'longitude', 'police_district']
data = retrieve_data_from_gcs(service_account_key, 
                              project_id,
                              bucket_name,
                              f"sf_police_report/{datetime.date.today()}.json",
                              key_list)

# %%
data[:6]
# Out:
# [['2025-08-26T23:17:00.000',
#   '2025-08-26T23:17:00.000',
#   '07041',
#   'Recovered Vehicle',
#   'Vehicle, Recovered, Auto',
#   None,
#   None,
#   'Out of SF'],
#  ['2025-08-27T00:37:00.000',
#   '2025-08-27T00:37:00.000',
#   '04134',
#   'Assault',
#   'Battery',
#   '37.78041458129883',
#   '-122.44901275634766',
#   'Park'],
#  ['2025-07-17T15:00:00.000',
#   '2025-08-27T11:55:00.000',
#   '09027',
#   'Fraud',
#   'False Personation',
#   '37.775177001953125',
#   '-122.45135498046875',
#   'Park'],
#  ['2025-08-23T21:30:00.000',
#   '2025-08-24T14:53:00.000',
#   '06244',
#   'Larceny Theft',
#   'Theft, From Locked Vehicle, >$950',
#   '37.77455139160156',
#   '-122.42250061035156',
#   'Northern'],
#  ['2025-08-15T12:00:00.000',
#   '2025-08-24T19:10:00.000',
#   '71000',
#   'Lost Property',
#   'Lost Property',
#   '37.76966094970703',
#   '-122.44964599609375',
#   'Park'],
#  ['2025-08-15T21:45:00.000',
#   '2025-08-16T10:39:00.000',
#   '07026',
#   'Motor Vehicle Theft',
#   'Vehicle, Stolen, Other Vehicle',
#   '37.77157211303711',
#   '-122.44218444824219',
#   'Park']]
